# %%
import pycaret
import pandas as pd 
from pycaret.datasets import get_data
from pycaret.clustering import *

# %%
file_path = 'dataset/n_vima.csv'
data = pd.read_csv(file_path, quotechar='"', delimiter=";")
s = setup(data, session_id = 123)
from pycaret.clustering import ClusteringExperiment
exp = ClusteringExperiment()
# Out:
# <style type="text/css">
# #T_b12d0_row5_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_b12d0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b12d0_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_b12d0_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b12d0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b12d0_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_b12d0_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_b12d0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b12d0_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_b12d0_row1_col1" class="data row1 col1" >(1031, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_b12d0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b12d0_row2_col0" class="data row2 col0" >Transformed data shape</td>
#       <td id="T_b12d0_row2_col1" class="data row2 col1" >(1031, 3617)</td>
#     </tr>
#     <tr>
#       <th id="T_b12d0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b12d0_row3_col0" class="data row3 col0" >Numeric features</td>
#       <td id="T_b12d0_row3_col1" class="data row3 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_b12d0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b12d0_row4_col0" class="data row4 col0" >Categorical features</td>
#       <td id="T_b12d0_row4_col1" class="data row4 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_b12d0_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b12d0_row5_col0" class="data row5 col0" >Preprocess</td>
#       <td id="T_b12d0_row5_col1" class="data row5 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_b12d0_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b12d0_row6_col0" class="data row6 col0" >Imputation type</td>
#       <td id="T_b12d0_row6_col1" class="data row6 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_b12d0_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b12d0_row7_col0" class="data row7 col0" >Numeric imputation</td>
#       <td id="T_b12d0_row7_col1" class="data row7 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_b12d0_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b12d0_row8_col0" class="data row8 col0" >Categorical imputation</td>
#       <td id="T_b12d0_row8_col1" class="data row8 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_b12d0_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b12d0_row9_col0" class="data row9 col0" >Maximum one-hot encoding</td>
#       <td id="T_b12d0_row9_col1" class="data row9 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_b12d0_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_b12d0_row10_col0" class="data row10 col0" >Encoding method</td>
#       <td id="T_b12d0_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_b12d0_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_b12d0_row11_col0" class="data row11 col0" >CPU Jobs</td>
#       <td id="T_b12d0_row11_col1" class="data row11 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_b12d0_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_b12d0_row12_col0" class="data row12 col0" >Use GPU</td>
#       <td id="T_b12d0_row12_col1" class="data row12 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b12d0_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_b12d0_row13_col0" class="data row13 col0" >Log Experiment</td>
#       <td id="T_b12d0_row13_col1" class="data row13 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b12d0_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_b12d0_row14_col0" class="data row14 col0" >Experiment Name</td>
#       <td id="T_b12d0_row14_col1" class="data row14 col1" >cluster-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_b12d0_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_b12d0_row15_col0" class="data row15 col0" >USI</td>
#       <td id="T_b12d0_row15_col1" class="data row15 col1" >26bd</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Crear un modelo de clustering (por ejemplo, K-Means)
kmeans = create_model('hclust', num_clusters=3)

# Asignar clusters al DataFrame
df_with_clusters = assign_model(kmeans)

# Imprimir los datos con los clusters asignados
print(df_with_clusters.head())
# Out:
# <style type="text/css">
# </style>
# <table id="T_b971c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b971c_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_b971c_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_b971c_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_b971c_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_b971c_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_b971c_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b971c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b971c_row0_col0" class="data row0 col0" >0.8663</td>
#       <td id="T_b971c_row0_col1" class="data row0 col1" >1831.5227</td>
#       <td id="T_b971c_row0_col2" class="data row0 col2" >0.4252</td>
#       <td id="T_b971c_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_b971c_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_b971c_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
#   EMPRESA     ARTICULO TIPO_MATERIAL  CODIGO_FAMILIA PESO_NETO  \
# 0     GVD         S201             V              98         1
# 1     GVD         S620             V              91         1
# 2     GVD  00311004056             A              96    0,4536
# 3     GVD  00311004058             A              96    0,4536
# 4     GVD  00311004077             A              96    0,4536
#
#    MULTIPRESENTACION STOCK_ACTUAL TOTAL_CANTIDAD_MOVS    PMP  \
# 0                  1            0                   0      0
# 1                  1       3317,3               77681  192,6
# 2                  1         6400               23680      0
# 3                  1        14850                1980      0
# 4                  1         6336                3168      0
#
#   TOTAL_IMPORTE_MOVS  TOTAL_MOVS    Cluster
# 0                  0           2  Cluster 1
# 1         14961360,6        4834  Cluster 0
# 2                  0          18  Cluster 1
# 3                  0           2  Cluster 1
# 4                  0           2  Cluster 1

# %%
kmeans_cluster = assign_model(kmeans)
kmeans_cluster
# Out:
#       EMPRESA  ARTICULO TIPO_MATERIAL CODIGO_FAMILIA PESO_NETO  \
# 0           1      9533             P           000B         1
# 1           1      9538             P           000B         1
# 2           1      9565             P           000B         1
# 3           1      9570             P           000A         1
# 4           1      9590             P           000B         1
# ...       ...       ...           ...            ...       ...
# 1374        1     38560             V            000         1
# 1375        1     38562             P           000B         1
# 1376        1     38570             M           029A         1
# 1377        1     38580             V            000         1
# 1378        1     38622             P          008PM         1
#
#       MULTIPRESENTACION STOCK_ACTUAL TOTAL_CANTIDAD_MOVS       PMP  \
# 0                     1       552,43              164,57     14100
# 1                     1          100                  40         0
# 2                     1          4,9               12,54         0
# 3                     1            0               10,84         0
# 4                     1          8,4                0,01    679000
# ...                 ...          ...                 ...       ...
# 1374                  1          129                 122         0
# 1375                  1        26,86                4,17    119700
# 1376                  1           34               13630  34816,57
# 1377                  1            0                2000         0
# 1378                  1          130                 630    198,45
#
#      TOTAL_IMPORTE_MOVS  TOTAL_MOVS    Cluster
# 0               2320437           2  Cluster 0
# 1                     0           1  Cluster 0
# 2                     0           4  Cluster 0
# 3                     0           1  Cluster 0
# 4                  6790           2  Cluster 0
# ...                 ...         ...        ...
# 1374                  0           4  Cluster 1
# 1375             499149           2  Cluster 1
# 1376        474549849,1         157  Cluster 1
# 1377                  0           1  Cluster 1
# 1378           125023,5           1  Cluster 1
#
# [1379 rows x 12 columns]

# %%
evaluate_model(kmeans)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…
