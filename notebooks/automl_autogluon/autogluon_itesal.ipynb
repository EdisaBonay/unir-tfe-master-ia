# %%
from autogluon.tabular import TabularDataset, TabularPredictor
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, precision_score, recall_score, f1_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier, StackingClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
import xgboost as xgb
import matplotlib.pyplot as plt
import seaborn as sns
from imblearn.over_sampling import SMOTE
from sklearn.linear_model import LogisticRegression

# %%
# Cargar el dataset
file_path = 'dataset/itesal.csv'
data = pd.read_csv("dataset/itesal.csv", quotechar='"', delimiter=";")

columns_to_drop = ['EMPRESA', 'NUMERO_FACTURA', 'NUMERO_ASIENTO_BORRADOR', 'TIPO_FACTURA', 'DIARIO', 'IMPORTE_COBRADO_FRA', 'CUENTA_CONTABLE','NUM_EFECTOS_COBRADOS', 'NUM_EFECTOS_PARCIAL', 'NUM_EFECTOS_IMPAGADO', 'NUM_EFECTOS_FUERA_PLAZO', 'NUM_EFECTOS_PDTE_EN_PLAZO']
data.drop(columns=columns_to_drop, inplace=True)

# %%
# Split the data into training and testing sets
train_data = data.sample(frac=0.8, random_state=0)
test_data = data.drop(train_data.index)

# %%
# load the data into an autogluon tabular dataset
dataset = TabularDataset(train_data)

# %%
dataset.head()
# Out:
#        EJERCICIO NUMERO_SERIE  ORGANIZACION_COMERCIAL  CLIENTE FECHA_FACTURA  \
# 47759       2021          F01                     101   100123    20/11/2021
# 53583       2021          F73                     703   700072    15/09/2021
# 20900       2019          F01                     101   100158    31/01/2019
# 73780       2023          F75                     901   900000    03/01/2023
# 3046        2018          F61                     601   600670    15/11/2018
#
#        MES_FACTURA DIVISA FORMA_COBRO  CENTRO_CONTABLE LIQUIDO_FACTURA  \
# 47759           11    EUR        TR10                1       134324,07
# 53583            9    EUR        PG15                7          246,79
# 20900            1    EUR        PG60                1         6112,74
# 73780            1    EUR         CON                7          119,14
# 3046            11    EUR        RN60                6         1968,34
#
#       ALBARAN_FACTURA ENVIO_ELECTRONICO FECHA_CONTABILIZACION  \
# 47759               N                SI            20/11/2021
# 53583               N                SI            15/09/2021
# 20900               N                SI            31/01/2019
# 73780               S                SI            03/01/2023
# 3046                N                NO            15/11/2018
#
#        TIENE_DESCUENTO  COUNT_TIPOS_TRANSACCION MAX_FECHA_COBRO  \
# 47759                1                      1.0      07/12/2021
# 53583                0                      1.0      24/09/2021
# 20900                0                      1.0             NaN
# 73780                0                      1.0      04/01/2023
# 3046                 0                      1.0      28/12/2018
#
#        NUM_EFECTOS_FACTURA  CATEGORIA_FACTURA
# 47759                    1                  1
# 53583                    1                  2
# 20900                    1                 -1
# 73780                    1                  1
# 3046                     1                  1

# %%
label = 'CATEGORIA_FACTURA'
dataset[label].describe()
# Out:
# count    63439.000000
# mean         1.418843
# std          0.901235
# min         -2.000000
# 25%          1.000000
# 50%          2.000000
# 75%          2.000000
# max          2.000000
# Name: CATEGORIA_FACTURA, dtype: float64

# %%
predictor = TabularPredictor(label=label).fit(dataset, time_limit=120, presets='best_quality')
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20240626_105526"
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.10.0
# Operating System:   Darwin
# Platform Machine:   arm64
# Platform Version:   Darwin Kernel Version 23.5.0: Wed May  1 20:13:18 PDT 2024; root:xnu-10063.121.3~5/RELEASE_ARM64_T6030
# CPU Count:          11
# Memory Avail:       13.76 GB / 36.00 GB (38.2%)
# Disk Space Avail:   128.41 GB / 460.43 GB (27.9%)
# ===================================================
# Presets specified: ['best_quality']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 30s of the 120s of remaining time (25%).
# 	Running DyStack sub-fit in a ray process to avoid memory leakage. Enabling ray logging (enable_ray_logging=True). Specify `ds_args={'enable_ray_logging': False}` if you experience logging issues.
# 2024-06-26 12:55:30,064	INFO worker.py:1743 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8265
# 		Context path: "AutogluonModels/ag-20240626_105526/ds_sub_fit/sub_fit_ho"
# (_dystack pid=49825) Running DyStack sub-fit ...
# (_dystack pid=49825) Beginning AutoGluon training ... Time limit = 26s
# (_dystack pid=49825) AutoGluon will save models to "AutogluonModels/ag-20240626_105526/ds_sub_fit/sub_fit_ho"
# (_dystack pid=49825) Train Data Rows:    56390
# (_dystack pid=49825) Train Data Columns: 17
# (_dystack pid=49825) Label Column:       CATEGORIA_FACTURA
# (_dystack pid=49825) Problem Type:       multiclass
# (_dystack pid=49825) Preprocessing data ...
# (_dystack pid=49825) Train Data Class Count: 5
# (_dystack pid=49825) Using Feature Generators to preprocess the data ...
# (_dystack pid=49825) Fitting AutoMLPipelineFeatureGenerator...
# (_dystack pid=49825) 	Available Memory:                    14127.62 MB
# (_dystack pid=49825) 	Train Data (Original)  Memory Usage: 33.48 MB (0.2% of available memory)
# (_dystack pid=49825) 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# (_dystack pid=49825) 	Stage 1 Generators:
# (_dystack pid=49825) 		Fitting AsTypeFeatureGenerator...
# (_dystack pid=49825) 			Note: Converting 4 features to boolean dtype as they only contain 2 unique values.
# (_dystack pid=49825) 	Stage 2 Generators:
# (_dystack pid=49825) 		Fitting FillNaFeatureGenerator...
# (_dystack pid=49825) 	Stage 3 Generators:
# (_dystack pid=49825) 		Fitting IdentityFeatureGenerator...
# (_dystack pid=49825) 		Fitting CategoryFeatureGenerator...
# (_dystack pid=49825) 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# (_dystack pid=49825) 		Fitting DatetimeFeatureGenerator...
# (_dystack pid=49825) 	Stage 4 Generators:
# (_dystack pid=49825) 		Fitting DropUniqueFeatureGenerator...
# (_dystack pid=49825) 	Stage 5 Generators:
# (_dystack pid=49825) 		Fitting DropDuplicatesFeatureGenerator...
# (_dystack pid=49825) 	Types of features in original data (raw dtype, special dtypes):
# (_dystack pid=49825) 		('float', [])                      : 1 | ['COUNT_TIPOS_TRANSACCION']
# (_dystack pid=49825) 		('int', [])                        : 7 | ['EJERCICIO', 'ORGANIZACION_COMERCIAL', 'CLIENTE', 'MES_FACTURA', 'CENTRO_CONTABLE', ...]
# (_dystack pid=49825) 		('object', [])                     : 6 | ['NUMERO_SERIE', 'DIVISA', 'FORMA_COBRO', 'LIQUIDO_FACTURA', 'ALBARAN_FACTURA', ...]
# (_dystack pid=49825) 		('object', ['datetime_as_object']) : 3 | ['FECHA_FACTURA', 'FECHA_CONTABILIZACION', 'MAX_FECHA_COBRO']
# (_dystack pid=49825) 	Types of features in processed data (raw dtype, special dtypes):
# (_dystack pid=49825) 		('category', [])             : 3 | ['NUMERO_SERIE', 'FORMA_COBRO', 'LIQUIDO_FACTURA']
# (_dystack pid=49825) 		('float', [])                : 1 | ['COUNT_TIPOS_TRANSACCION']
# (_dystack pid=49825) 		('int', [])                  : 6 | ['EJERCICIO', 'ORGANIZACION_COMERCIAL', 'CLIENTE', 'MES_FACTURA', 'CENTRO_CONTABLE', ...]
# (_dystack pid=49825) 		('int', ['bool'])            : 4 | ['DIVISA', 'ALBARAN_FACTURA', 'ENVIO_ELECTRONICO', 'TIENE_DESCUENTO']
# (_dystack pid=49825) 		('int', ['datetime_as_int']) : 9 | ['FECHA_FACTURA', 'FECHA_FACTURA.month', 'FECHA_FACTURA.day', 'FECHA_FACTURA.dayofweek', 'MAX_FECHA_COBRO', ...]
# (_dystack pid=49825) 	0.6s = Fit runtime
# (_dystack pid=49825) 	17 features in original data used to generate 23 features in processed data.
# (_dystack pid=49825) 	Train Data (Processed) Memory Usage: 7.32 MB (0.1% of available memory)
# (_dystack pid=49825) Data preprocessing and feature engineering runtime = 0.61s ...
# (_dystack pid=49825) AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# (_dystack pid=49825) 	To change this, specify the eval_metric parameter of Predictor()
# (_dystack pid=49825) Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# (_dystack pid=49825) User-specified model hyperparameters to be fit:
# (_dystack pid=49825) {
# (_dystack pid=49825) 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# (_dystack pid=49825) 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# (_dystack pid=49825) 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# (_dystack pid=49825) 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# (_dystack pid=49825) 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# (_dystack pid=49825) 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=49825) 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=49825) 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# (_dystack pid=49825) }
# (_dystack pid=49825) AutoGluon will fit 2 stack levels (L1 to L2) ...
# (_dystack pid=49825) Fitting 110 L1 models ...
# (_dystack pid=49825) Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 17.07s of the 25.61s of remaining time.
# (_dystack pid=49825) 	0.8048	 = Validation score   (accuracy)
# (_dystack pid=49825) 	0.01s	 = Training   runtime
# (_dystack pid=49825) 	1.95s	 = Validation runtime
# (_dystack pid=49825) Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 14.25s of the 22.79s of remaining time.
# (_dystack pid=49825) 	0.8161	 = Validation score   (accuracy)
# (_dystack pid=49825) 	0.01s	 = Training   runtime
# (_dystack pid=49825) 	1.83s	 = Validation runtime
# (_dystack pid=49825) Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 12.36s of the 20.9s of remaining time.
# (_dystack pid=49825) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.60%)
# (_dystack pid=49825) 	0.7974	 = Validation score   (accuracy)
# (_dystack pid=49825) 	8.8s	 = Training   runtime
# (_dystack pid=49825) 	0.72s	 = Validation runtime
# (_dystack pid=49825) Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 2.2s of the 10.73s of remaining time.
# (_dystack pid=49825) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.44%)
# (_dystack pid=49825) 	0.8237	 = Validation score   (accuracy)
# (_dystack pid=49825) 	2.07s	 = Training   runtime
# (_dystack pid=49825) 	1.64s	 = Validation runtime
# (_dystack pid=49825) Fitting model: WeightedEnsemble_L2 ... Training model for up to 25.62s of the 6.5s of remaining time.
# (_dystack pid=49825) 	Ensemble Weights: {'LightGBMXT_BAG_L1': 0.667, 'KNeighborsDist_BAG_L1': 0.333}
# (_dystack pid=49825) 	0.8578	 = Validation score   (accuracy)
# (_dystack pid=49825) 	0.48s	 = Training   runtime
# (_dystack pid=49825) 	0.0s	 = Validation runtime
# (_dystack pid=49825) Fitting 108 L2 models ...
# (_dystack pid=49825) Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 6.01s of the 5.98s of remaining time.
# (_dystack pid=49825) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.85%)
# (_dystack pid=49825) 	0.8687	 = Validation score   (accuracy)
# (_dystack pid=49825) 	5.29s	 = Training   runtime
# (_dystack pid=49825) 	0.58s	 = Validation runtime
# (_dystack pid=49825) Fitting model: WeightedEnsemble_L3 ... Training model for up to 25.62s of the -1.08s of remaining time.
# (_dystack pid=49825) 	Ensemble Weights: {'NeuralNetFastAI_BAG_L2': 0.611, 'LightGBMXT_BAG_L1': 0.222, 'KNeighborsDist_BAG_L1': 0.111, 'NeuralNetFastAI_BAG_L1': 0.056}
# (_dystack pid=49825) 	0.8711	 = Validation score   (accuracy)
# (_dystack pid=49825) 	0.51s	 = Training   runtime
# (_dystack pid=49825) 	0.0s	 = Validation runtime
# (_dystack pid=49825) AutoGluon training complete, total runtime = 27.83s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 2062.9 rows/s (7049 batch size)
# (_dystack pid=49825) TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20240626_105526/ds_sub_fit/sub_fit_ho")
# (_dystack pid=49825) Deleting DyStack predictor artifacts (clean_up_fits=True) ...
# Leaderboard on holdout data (DyStack):
#                     model  score_holdout  score_val eval_metric  pred_time_test  pred_time_val   fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0  NeuralNetFastAI_BAG_L2       0.882111   0.868665    accuracy        1.869349       6.726547  16.198925                 0.392536                0.583096           5.292690            2       True          6
# 1     WeightedEnsemble_L3       0.880976   0.871147    accuracy        1.870633       6.729845  16.706000                 0.001285                0.003298           0.507076            3       True          7
# 2     WeightedEnsemble_L2       0.865229   0.857776    accuracy        0.570819       3.478784   2.565007                 0.001198                0.003203           0.477173            2       True          5
# 3       LightGBMXT_BAG_L1       0.827210   0.823692    accuracy        0.275923       1.644349   2.073667                 0.275923                1.644349           2.073667            1       True          4
# 4   KNeighborsDist_BAG_L1       0.826784   0.816120    accuracy        0.293698       1.831232   0.014167                 0.293698                1.831232           0.014167            1       True          2
# 5   KNeighborsUnif_BAG_L1       0.812598   0.804806    accuracy        0.300845       1.951606   0.014113                 0.300845                1.951606           0.014113            1       True          1
# 6  NeuralNetFastAI_BAG_L1       0.811888   0.797429    accuracy        0.606346       0.716264   8.804287                 0.606346                0.716264           8.804287            1       True          3
# 	1	 = Optimal   num_stack_levels (Stacked Overfitting Occurred: False)
# 	35s	 = DyStack   runtime |	85s	 = Remaining runtime
# Starting main fit with num_stack_levels=1.
# 	For future fit calls on this dataset, you can skip DyStack to save time: `predictor.fit(..., dynamic_stacking=False, num_stack_levels=1)`
# Beginning AutoGluon training ... Time limit = 85s
# AutoGluon will save models to "AutogluonModels/ag-20240626_105526"
# Train Data Rows:    63439
# Train Data Columns: 17
# Label Column:       CATEGORIA_FACTURA
# Problem Type:       multiclass
# Preprocessing data ...
# Train Data Class Count: 5
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    15898.89 MB
# 	Train Data (Original)  Memory Usage: 37.68 MB (0.2% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 4 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 		Fitting DatetimeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])                      : 1 | ['COUNT_TIPOS_TRANSACCION']
# 		('int', [])                        : 7 | ['EJERCICIO', 'ORGANIZACION_COMERCIAL', 'CLIENTE', 'MES_FACTURA', 'CENTRO_CONTABLE', ...]
# 		('object', [])                     : 6 | ['NUMERO_SERIE', 'DIVISA', 'FORMA_COBRO', 'LIQUIDO_FACTURA', 'ALBARAN_FACTURA', ...]
# 		('object', ['datetime_as_object']) : 3 | ['FECHA_FACTURA', 'FECHA_CONTABILIZACION', 'MAX_FECHA_COBRO']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])             : 3 | ['NUMERO_SERIE', 'FORMA_COBRO', 'LIQUIDO_FACTURA']
# 		('float', [])                : 1 | ['COUNT_TIPOS_TRANSACCION']
# 		('int', [])                  : 6 | ['EJERCICIO', 'ORGANIZACION_COMERCIAL', 'CLIENTE', 'MES_FACTURA', 'CENTRO_CONTABLE', ...]
# 		('int', ['bool'])            : 4 | ['DIVISA', 'ALBARAN_FACTURA', 'ENVIO_ELECTRONICO', 'TIENE_DESCUENTO']
# 		('int', ['datetime_as_int']) : 9 | ['FECHA_FACTURA', 'FECHA_FACTURA.month', 'FECHA_FACTURA.day', 'FECHA_FACTURA.dayofweek', 'MAX_FECHA_COBRO', ...]
# 	0.7s = Fit runtime
# 	17 features in original data used to generate 23 features in processed data.
# 	Train Data (Processed) Memory Usage: 8.23 MB (0.1% of available memory)
# Data preprocessing and feature engineering runtime = 0.77s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 110 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 56.35s of the 84.54s of remaining time.
# 	0.8099	 = Validation score   (accuracy)
# 	0.02s	 = Training   runtime
# 	2.35s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 53.02s of the 81.21s of remaining time.
# 	0.8231	 = Validation score   (accuracy)
# 	0.03s	 = Training   runtime
# 	2.31s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 50.64s of the 78.83s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.60%)
# 	0.8477	 = Validation score   (accuracy)
# 	37.07s	 = Training   runtime
# 	0.57s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 12.35s of the 40.55s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.45%)
# 	0.8807	 = Validation score   (accuracy)
# 	10.66s	 = Training   runtime
# 	24.03s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 84.55s of the 25.26s of remaining time.
# 	Ensemble Weights: {'LightGBMXT_BAG_L1': 0.588, 'KNeighborsDist_BAG_L1': 0.235, 'NeuralNetFastAI_BAG_L1': 0.176}
# 	0.8889	 = Validation score   (accuracy)
# 	0.44s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 108 L2 models ...
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 24.81s of the 24.78s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.96%)
# 	0.893	 = Validation score   (accuracy)
# 	17.99s	 = Training   runtime
# 	0.66s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 5.78s of the 5.75s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.78%)
# 	0.9018	 = Validation score   (accuracy)
# 	5.24s	 = Training   runtime
# 	2.28s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 84.55s of the -1.52s of remaining time.
# 	Ensemble Weights: {'LightGBMXT_BAG_L2': 1.0}
# 	0.9018	 = Validation score   (accuracy)
# 	0.47s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 87.33s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 288.7 rows/s (7930 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20240626_105526")

# %%
predictor.fit_summary(show_plot=True)
# Out:
# *** Summary of fit() ***
# Estimated performance of each model:
#                     model  score_val eval_metric  pred_time_val   fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0       LightGBMXT_BAG_L2   0.901795    accuracy      31.539004  53.019026                2.280306           5.235901            2       True          7
# 1     WeightedEnsemble_L3   0.901795    accuracy      31.541865  53.490664                0.002861           0.471638            3       True          8
# 2  NeuralNetFastAI_BAG_L2   0.893031    accuracy      29.921015  65.771923                0.662316          17.988798            2       True          6
# 3     WeightedEnsemble_L2   0.888870    accuracy      26.916129  48.200179                0.003044           0.437035            2       True          5
# 4       LightGBMXT_BAG_L1   0.880704    accuracy      24.032576  10.663714               24.032576          10.663714            1       True          4
# 5  NeuralNetFastAI_BAG_L1   0.847728    accuracy       0.570759  37.071932                0.570759          37.071932            1       True          3
# 6   KNeighborsDist_BAG_L1   0.823074    accuracy       2.309749   0.027498                2.309749           0.027498            1       True          2
# 7   KNeighborsUnif_BAG_L1   0.809865    accuracy       2.345614   0.019981                2.345614           0.019981            1       True          1
# Number of models trained: 8
# Types of models trained:
# {'StackerEnsembleModel_KNN', 'StackerEnsembleModel_NNFastAiTabular', 'WeightedEnsembleModel', 'StackerEnsembleModel_LGB'}
# Bagging used: True  (with 8 folds)
# Multi-layer stack-ensembling used: True  (with 3 levels)
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('category', [])             : 3 | ['NUMERO_SERIE', 'FORMA_COBRO', 'LIQUIDO_FACTURA']
# ('float', [])                : 1 | ['COUNT_TIPOS_TRANSACCION']
# ('int', [])                  : 6 | ['EJERCICIO', 'ORGANIZACION_COMERCIAL', 'CLIENTE', 'MES_FACTURA', 'CENTRO_CONTABLE', ...]
# ('int', ['bool'])            : 4 | ['DIVISA', 'ALBARAN_FACTURA', 'ENVIO_ELECTRONICO', 'TIENE_DESCUENTO']
# ('int', ['datetime_as_int']) : 9 | ['FECHA_FACTURA', 'FECHA_FACTURA.month', 'FECHA_FACTURA.day', 'FECHA_FACTURA.dayofweek', 'MAX_FECHA_COBRO', ...]
# *** End of fit() summary ***
# /Users/bonay/.pyenv/versions/3.10.0/envs/gal_lua/lib/python3.10/site-packages/autogluon/core/utils/plots.py:169: UserWarning: AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"
#   warnings.warn('AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"')
# {'model_types': {'KNeighborsUnif_BAG_L1': 'StackerEnsembleModel_KNN',
#   'KNeighborsDist_BAG_L1': 'StackerEnsembleModel_KNN',
#   'NeuralNetFastAI_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'LightGBMXT_BAG_L1': 'StackerEnsembleModel_LGB',
#   'WeightedEnsemble_L2': 'WeightedEnsembleModel',
#   'NeuralNetFastAI_BAG_L2': 'StackerEnsembleModel_NNFastAiTabular',
#   'LightGBMXT_BAG_L2': 'StackerEnsembleModel_LGB',
#   'WeightedEnsemble_L3': 'WeightedEnsembleModel'},
#  'model_performance': {'KNeighborsUnif_BAG_L1': 0.8098645943347152,
#   'KNeighborsDist_BAG_L1': 0.8230741342076641,
#   'NeuralNetFastAI_BAG_L1': 0.8477277384574158,
#   'LightGBMXT_BAG_L1': 0.8807042986175696,
#   'WeightedEnsemble_L2': 0.8888696227872445,
#   'NeuralNetFastAI_BAG_L2': 0.8930311007424455,
#   'LightGBMXT_BAG_L2': 0.9017954255268841,
#   'WeightedEnsemble_L3': 0.9017954255268841},
#  'model_best': 'WeightedEnsemble_L3',
#  'model_paths': {'KNeighborsUnif_BAG_L1': ['KNeighborsUnif_BAG_L1'],
#   'KNeighborsDist_BAG_L1': ['KNeighborsDist_BAG_L1'],
#   'NeuralNetFastAI_BAG_L1': ['NeuralNetFastAI_BAG_L1'],
#   'LightGBMXT_BAG_L1': ['LightGBMXT_BAG_L1'],
#   'WeightedEnsemble_L2': ['WeightedEnsemble_L2'],
#   'NeuralNetFastAI_BAG_L2': ['NeuralNetFastAI_BAG_L2'],
#   'LightGBMXT_BAG_L2': ['LightGBMXT_BAG_L2'],
#   'WeightedEnsemble_L3': ['WeightedEnsemble_L3']},
#  'model_fit_times': {'KNeighborsUnif_BAG_L1': 0.01998114585876465,
#   'KNeighborsDist_BAG_L1': 0.02749800682067871,
#   'NeuralNetFastAI_BAG_L1': 37.07193207740784,
#   'LightGBMXT_BAG_L1': 10.663714170455933,
#   'WeightedEnsemble_L2': 0.43703484535217285,
#   'NeuralNetFastAI_BAG_L2': 17.988797903060913,
#   'LightGBMXT_BAG_L2': 5.23590087890625,
#   'WeightedEnsemble_L3': 0.4716379642486572},
#  'model_pred_times': {'KNeighborsUnif_BAG_L1': 2.345613718032837,
#   'KNeighborsDist_BAG_L1': 2.309749126434326,
#   'NeuralNetFastAI_BAG_L1': 0.5707592964172363,
#   'LightGBMXT_BAG_L1': 24.032576322555542,
#   'WeightedEnsemble_L2': 0.0030438899993896484,
#   'NeuralNetFastAI_BAG_L2': 0.662316083908081,
#   'LightGBMXT_BAG_L2': 2.2803056240081787,
#   'WeightedEnsemble_L3': 0.00286102294921875},
#  'num_bag_folds': 8,
#  'max_stack_level': 3,
#  'num_classes': 5,
#  'model_hyperparams': {'KNeighborsUnif_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'KNeighborsDist_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBMXT_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'WeightedEnsemble_L2': {'use_orig_features': False,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBMXT_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'WeightedEnsemble_L3': {'use_orig_features': False,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True}},
#  'leaderboard':                     model  score_val eval_metric  pred_time_val   fit_time  \
#  0       LightGBMXT_BAG_L2   0.901795    accuracy      31.539004  53.019026
#  1     WeightedEnsemble_L3   0.901795    accuracy      31.541865  53.490664
#  2  NeuralNetFastAI_BAG_L2   0.893031    accuracy      29.921015  65.771923
#  3     WeightedEnsemble_L2   0.888870    accuracy      26.916129  48.200179
#  4       LightGBMXT_BAG_L1   0.880704    accuracy      24.032576  10.663714
#  5  NeuralNetFastAI_BAG_L1   0.847728    accuracy       0.570759  37.071932
#  6   KNeighborsDist_BAG_L1   0.823074    accuracy       2.309749   0.027498
#  7   KNeighborsUnif_BAG_L1   0.809865    accuracy       2.345614   0.019981
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
#  0                2.280306           5.235901            2       True
#  1                0.002861           0.471638            3       True
#  2                0.662316          17.988798            2       True
#  3                0.003044           0.437035            2       True
#  4               24.032576          10.663714            1       True
#  5                0.570759          37.071932            1       True
#  6                2.309749           0.027498            1       True
#  7                2.345614           0.019981            1       True
#
#     fit_order
#  0          7
#  1          8
#  2          6
#  3          5
#  4          4
#  5          3
#  6          2
#  7          1  }

# %%
y_pred = predictor.predict(test_data.drop(columns=[label]))
y_pred.head()
# Out:
# 2     1
# 10    2
# 13   -1
# 20    2
# 21    1
# Name: CATEGORIA_FACTURA, dtype: int64

# %%
predictor.evaluate(test_data, silent=True)
# Out:
# {'accuracy': 0.9059899117276167,
#  'balanced_accuracy': 0.6489736429920778,
#  'mcc': 0.8230132562939034}

# %%
predictor.leaderboard(test_data)
# Out:
#                     model  score_test  score_val eval_metric  pred_time_test  \
# 0  NeuralNetFastAI_BAG_L2    0.908071   0.901764    accuracy        5.629897
# 1     WeightedEnsemble_L3    0.905990   0.904381    accuracy        5.631608
# 2     WeightedEnsemble_L2    0.898676   0.897177    accuracy        4.271829
# 3  NeuralNetFastAI_BAG_L1    0.896658   0.880625    accuracy        0.789692
# 4       LightGBMXT_BAG_L1    0.884111   0.882927    accuracy        2.881481
# 5   KNeighborsDist_BAG_L1    0.815637   0.823074    accuracy        0.598751
# 6   KNeighborsUnif_BAG_L1    0.801955   0.809865    accuracy        0.639173
#
#    pred_time_val    fit_time  pred_time_test_marginal  pred_time_val_marginal  \
# 0      32.511357  302.778045                 0.720800                0.779316
# 1      32.514757  303.284977                 0.001711                0.003400
# 2      27.716147  234.879062                 0.001905                0.004233
# 3       0.727567  187.199307                 0.789692                0.727567
# 4      23.130464   46.899360                 2.881481               23.130464
# 5       3.853883    0.051163                 0.598751                3.853883
# 6       4.020127    0.034107                 0.639173                4.020127
#
#    fit_time_marginal  stack_level  can_infer  fit_order
# 0          68.594108            2       True          6
# 1           0.506932            3       True          7
# 2           0.729232            2       True          5
# 3         187.199307            1       True          3
# 4          46.899360            1       True          4
# 5           0.051163            1       True          2
# 6           0.034107            1       True          1

# %%
predictor.feature_importance(test_data)
# Out:
# Computing feature importance via permutation shuffling for 17 features using 5000 rows with 5 shuffle sets...
# 	197.7s	= Expected runtime (39.54s per shuffle set)
# 	150.95s	= Actual runtime (Completed 5 of 5 shuffle sets)
#                          importance    stddev       p_value  n  p99_high  \
# MAX_FECHA_COBRO             0.38564  0.007516  1.730396e-08  5  0.401115
# FECHA_FACTURA               0.17504  0.006845  2.799814e-07  5  0.189133
# FORMA_COBRO                 0.14040  0.007559  1.004423e-06  5  0.155964
# NUMERO_SERIE                0.02884  0.002170  3.815949e-06  5  0.033308
# MES_FACTURA                 0.00856  0.002161  4.482600e-04  5  0.013009
# NUM_EFECTOS_FACTURA         0.00424  0.001381  1.179743e-03  5  0.007084
# ALBARAN_FACTURA             0.00364  0.000518  4.779941e-05  5  0.004706
# CENTRO_CONTABLE             0.00272  0.000832  9.306966e-04  5  0.004433
# ENVIO_ELECTRONICO           0.00264  0.001220  4.202007e-03  5  0.005152
# EJERCICIO                   0.00168  0.002419  9.770286e-02  5  0.006661
# ORGANIZACION_COMERCIAL      0.00120  0.001158  4.065736e-02  5  0.003583
# TIENE_DESCUENTO             0.00112  0.000179  7.550570e-05  5  0.001488
# CLIENTE                     0.00108  0.001487  8.987713e-02  5  0.004142
# COUNT_TIPOS_TRANSACCION     0.00080  0.000548  1.545292e-02  5  0.001928
# FECHA_CONTABILIZACION       0.00008  0.000415  3.442285e-01  5  0.000934
# DIVISA                      0.00004  0.000477  4.302649e-01  5  0.001023
# LIQUIDO_FACTURA            -0.00056  0.001846  7.326034e-01  5  0.003241
#
#                           p99_low
# MAX_FECHA_COBRO          0.370165
# FECHA_FACTURA            0.160947
# FORMA_COBRO              0.124836
# NUMERO_SERIE             0.024372
# MES_FACTURA              0.004111
# NUM_EFECTOS_FACTURA      0.001396
# ALBARAN_FACTURA          0.002574
# CENTRO_CONTABLE          0.001007
# ENVIO_ELECTRONICO        0.000128
# EJERCICIO               -0.003301
# ORGANIZACION_COMERCIAL  -0.001183
# TIENE_DESCUENTO          0.000752
# CLIENTE                 -0.001982
# COUNT_TIPOS_TRANSACCION -0.000328
# FECHA_CONTABILIZACION   -0.000774
# DIVISA                  -0.000943
# LIQUIDO_FACTURA         -0.004361

# %%
predictor.plo
